# %% [markdown]
# # Задание 3.6.1

# %%
import requests
with open ("dataset_3378_2.txt", "r") as file:
    for line in file.readlines():
        url = line.strip()
#print(url)
file_text = requests.get(url)
lines_list = file_text.text.splitlines()

print(file_text.text.splitlines()[1])
print(len(lines_list))
# Out:
# "Hell," said the Captain.
# 40

# %% [markdown]
# # Задание 3.6.2

# %%
import requests
url_dir = "https://stepic.org/media/attachments/course67/3.6.3/"
file_name = "dataset_3378_3.txt"
with open ("dataset_3378_3.txt", "r") as file:
    for line in file.readlines():
        url_first_file = line.strip()
file_text = requests.get(url_first_file)
print(url_first_file)

while True:
    file_name = file_text.text
    file_text = requests.get(url_dir + file_name)
    print(file_text.text)
    if len(file_text.text.splitlines()) > 1:
        if file_text.text.splitlines()[1].split()[0] == "We":
            break
print(file_name)
# Out:
# https://stepic.org/media/attachments/course67/3.6.3/699991.txt
# 396639.txt
# 835329.txt
# 344063.txt
# 194307.txt
# 195211.txt
# 769171.txt
# 153554.txt
# 680916.txt
# 335636.txt
# 935728.txt
# 081303.txt
# 792633.txt
# 668368.txt
# 647731.txt
# 904392.txt
# 684563.txt
# 997337.txt
# 329467.txt
# 366219.txt
# 730037.txt
# 310230.txt
# 104249.txt
# 382504.txt
# 433681.txt
# 507359.txt
# 293649.txt
# 011641.txt
# 717942.txt
# 258080.txt
# 569395.txt
# 756825.txt
# 921388.txt
# 437007.txt
# 004090.txt
# 362705.txt
# 145282.txt
# 990216.txt
# 645783.txt
# 451262.txt
# 193295.txt
# 777343.txt
# 324603.txt
# 888934.txt
# 138655.txt
# 818396.txt
# 290594.txt
# 478003.txt
# 276687.txt
# 703763.txt
# 712469.txt
# 064418.txt
# 246033.txt
# 356768.txt
# 504290.txt
# 629914.txt
# 062456.txt
# 658472.txt
# 037659.txt
# 351978.txt
# 523822.txt
# 653493.txt
# 859227.txt
# 878358.txt
# 944504.txt
# 457602.txt
# 548571.txt
# 090976.txt
# 965991.txt
# 138128.txt
# 255843.txt
# 797598.txt
# ...

# %%
file_text = requests.get(url_dir + "843785.txt")
print( file_text.text)
# Out:
# We are the champions, my friends,
# And we'll keep on fighting 'til the end.
# We are the champions.
# We are the champions.
# No time for losers
# 'Cause we are the champions of the world.

# %%
with open("dataset_3363_3.txt", "r") as file:
    counter = 0 
    for line in file.readlines():
        if counter == 0:
            print(line.split()[0])
        counter += 1
# Out:
# d
